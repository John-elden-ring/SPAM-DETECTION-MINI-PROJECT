# %%
import pandas as pd

df = pd.read_csv('Spam Email raw text for NLP.csv')
df.head()
# Out:
#    CATEGORY                                            MESSAGE  \
# 0         1  Dear Homeowner,\n\n \n\nInterest Rates are at ...
# 1         1  ATTENTION: This is a MUST for ALL Computer Use...
# 2         1  This is a multi-part message in MIME format.\n...
# 3         1  IMPORTANT INFORMATION:\n\n\n\nThe new domain n...
# 4         1  This is the bottom line.  If you can GIVE AWAY...
#
#                                 FILE_NAME
# 0  00249.5f45607c1bffe89f60ba1ec9f878039a
# 1  00373.ebe8670ac56b04125c25100a36ab0510
# 2  00214.1367039e50dc6b7adb0f2aa8aba83216
# 3  00210.050ffd105bd4e006771ee63cabc59978
# 4  00033.9babb58d9298daa2963d4f514193d7d6

# %%
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Adhik
# [nltk_data]     Puthenkattil\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package stopwords to C:\Users\Adhik
# [nltk_data]     Puthenkattil\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
tokenizer = nltk.RegexpTokenizer(r"\w+")
test_message = "Hey,, GGggGG feet it going? <HTML><bads> bads 'randoms' badly"
test_message_tokenized = tokenizer.tokenize(test_message)
test_message_tokenized
# Out:
# ['Hey',
#  'GGggGG',
#  'feet',
#  'it',
#  'going',
#  'HTML',
#  'bads',
#  'bads',
#  'randoms',
#  'badly']

# %%
test_message_lowercased = [t.lower() for t in test_message_tokenized]
test_message_lowercased
# Out:
# ['hey',
#  'gggggg',
#  'feet',
#  'it',
#  'going',
#  'html',
#  'bads',
#  'bads',
#  'randoms',
#  'badly']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
test_message_lemmatized_tokens = [lemmatizer.lemmatize(t) for t in test_message_lowercased]
test_message_lemmatized_tokens
# Out:
# ['hey',
#  'gggggg',
#  'foot',
#  'it',
#  'going',
#  'html',
#  'bad',
#  'bad',
#  'randoms',
#  'badly']

# %%
from nltk.corpus import stopwords

stopwords = stopwords.words('english')
test_message_useful_tokens = [t for t in test_message_lemmatized_tokens if t not in stopwords]
test_message_useful_tokens
# Out:
# ['hey', 'gggggg', 'foot', 'going', 'html', 'bad', 'bad', 'randoms', 'badly']

# %%
def message_to_token_list(s):
    tokens = tokenizer.tokenize(s)
    lowercased_tokens = [t.lower() for t in tokens]
    lemmatized_tokens = [lemmatizer.lemmatize(t) for t in lowercased_tokens]
    useful_tokens = [t for t  in lemmatized_tokens if t not in stopwords]
    return useful_tokens

# %%
df = df.sample(frac=1, random_state=1)
df = df.reset_index(drop=True) 

split_index = int(len(df) * 0.8)
train_df, test_df = df[:split_index], df[split_index:]
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)
train_df, test_df
# Out:
# (      CATEGORY                                            MESSAGE  \
#  0            1  IMPORTANT INFORMATION:\n\n\n\nThe new domain n...
#  1            1  ------=_NextPart_000_00C6_24D75C3A.C0588C07\n\...
#  2            0  Any plans for rolling Nessus RPMs for RH8?  Mi...
#  3            0  \n\n\n\nHijacker High (8/30) \n\nDalal Mughrab...
#  4            0  On Mon, Nov 25, 2002 at 06:54:49PM +0000, Phil...
#  ...        ...                                                ...
#  4631         1  Get your favorite Poker action at http://www.m...
#  4632         0  \n\n----- Original Message -----\n\nFrom: "Kra...
#  4633         0  use Perl Daily Newsletter\n\n\n\nIn this issue...
#  4634         0  \n\n--]> A Green once said that if the Spotted...
#  4635         1  <html>\n\n<head>\n\n<title>FREESTORES - MAKE M...
#
#                                     FILE_NAME
#  0     00416.7fa9ccac275fe2d97517554ecde57fbe
#  1     00370.549e569ab1b84fb13a4ea7d61f98f86d
#  2     01280.08e69f637d901fab10aec6c9492d068e
#  3     00894.5b21597d342d44631ebc33acf460883c
#  4     02478.40723f38488bddaf5a24ef2a91679c75
#  ...                                      ...
#  4631  00294.df27a988d82cc82296e33e6d727ac47e
#  4632  00661.e779083f6d4522af5231edf0b9371a1d
#  4633  01773.e0850dc6f3d7e902f61de852025ad50b
#  4634  00731.23dbba60cc6ea56f735599461109200d
#  4635  00483.50c5dda7dd4710798c15a85ade6e9f93
#
#  [4636 rows x 3 columns],
#        CATEGORY                                            MESSAGE  \
#  0            0  On Tue, Sep 17, 2002 at 10:19:13AM -0700, Chuc...
#  1            0  I'll agree that webforms are a pain in the ass...
#  2            1  This is a multi-part message in MIME format.\n...
#  3            0  \n\nGLM> Hate-lit rests on a premise that "the...
#  4            0  At 09:24 PM 8/3/02 -0700, Mr. FoRK wrote:\n\n\...
#  ...        ...                                                ...
#  1155         0  \n\n<snip>\n\n>Tracking it down showed that my...
#  1156         1  <html>\n\n\n\n<head>\n\n<meta http-equiv=3D"Co...
#  1157         0  ---------- Forwarded message ----------\n\nDat...
#  1158         0  Oh yeah, the link for more info:\n\n\n\nhttp:/...
#  1159         0  Robin Lynn Frank <rlfrank@paradigm-omega.com> ...
#
#                                     FILE_NAME
#  0     00602.2dc7ba42179a34e52badfe383f7fe08a
#  1     00799.160a04b5935b5a9610b4dc15951b5d30
#  2     00341.99b463b92346291f5848137f4a253966
#  3     01053.21ea199fc91688bd61caad77676702b8
#  4     00766.3c60b4a3900ab239864deb0f2c411577
#  ...                                      ...
#  1155  00290.2b079837bffa2f0dea4003cf99bc36e0
#  1156  00378.143069173c8ee0047916f124032367d1
#  1157  00767.d5b223070f2a19834daa88bc4338354d
#  1158  00756.2b2ec73ad20a4e0bdf31632ac019233b
#  1159  01364.eaba5be49d5662dd5e3f89a7f430e614
#
#  [1160 rows x 3 columns])

# %%
token_counter = {}

for message in train_df['MESSAGE']:
    message_as_token_list = message_to_token_list(message)
    for token in message_as_token_list:
        if token in token_counter:
            token_counter[token] += 1
        else:
            token_counter[token] = 1
len(token_counter)
# Out:
# 85600

# %%
token_counter
# Out:
# {'important': 309,
#  'information': 2096,
#  'new': 2735,
#  'domain': 274,
#  'name': 3612,
#  'finally': 171,
#  'available': 731,
#  'general': 362,
#  'public': 573,
#  'discount': 78,
#  'price': 709,
#  'register': 156,
#  'one': 3405,
#  'exciting': 61,
#  'biz': 130,
#  'info': 618,
#  'well': 997,
#  'original': 461,
#  'com': 12483,
#  'net': 5435,
#  '14': 512,
#  '95': 433,
#  'brand': 106,
#  'extension': 39,
#  'recently': 178,
#  'approved': 103,
#  'icann': 11,
#  'right': 2348,
#  'biggest': 72,
#  'benefit': 299,
#  'course': 447,
#  'currently': 291,
#  'e': 2822,
#  'much': 1045,
#  'easier': 130,
#  'attractive': 29,
#  'easy': 601,
#  'remember': 318,
#  'visit': 411,
#  'http': 15773,
#  'www': 8003,
#  'affordable': 48,
#  'today': 854,
#  'registration': 50,
#  'fee': 183,
#  'include': 429,
#  'full': 434,
#  'access': 533,
#  'use': 2265,
#  'control': 327,
#  'panel': 75,
#  'manage': 90,
#  'future': 565,
#  'sincerely': 98,
#  'administrator': 48,
#  'remove': 1035,
#  'email': 3835,
#  'address': 1751,
#  'promotional': 16,
#  'mailing': 2147,
#  'company': 1441,
#  'click': 2085,
#  'centralremovalservice': 12,
#  'cgi': 516,
#  'bin': 345,
#  '9358visa9': 1,
#  'l9': 1,
#  '_nextpart_000_00c6_24d75c3a': 1,
#  'c0588c07': 1,
#  'content': 2923,
#  'type': 2916,
#  'text': 2903,
#  'plain': 458,
#  'charset': 933,
#  'iso': 419,
#  '8859': 514,
#  '1': 9257,
#  'transfer': 703,
#  'encoding': 554,
#  'base64': 122,
#  'bg92zq0kv29ybgqgq2fwaxrhbcbhcm91ccbpcybhigdyb3vwig9miez1bmrp': 1,
#  'bmcgu291cmnlcyb0agf0ighlbhagynvzaw5lc3nlcyancndpdgggdghlaxig': 1,
#  'zmluyw5jawfsig5lzwrzliagv2ugy2fuihbyb3zpzgugv29ya2luzybdyxbp': 1,
#  'dgfsihrvicqxntasmdawia0kb24gyw4gdw5zzwn1cmvkigjhc2lzoyb3aglj': 1,
#  'acbjyw4gymugdxnlzcb0byb0ywtlignhcmugb2ygy2fzacbmbg93ia0kbmvl': 1,
#  'zhmsihbyb3zpzgugznvuzhmgzm9yigv4cgfuc2lvbibhbmqgb3rozxigbmvl': 1,
#  'zhmgew91cibidxnpbmvzcyboyxmgkfvtia0kynvzaw5lc3nlcybvbmx5ks4g': 1,
#  'ifdligfsc28gchvyy2hhc2ugsw52b2ljzxmsiefjy291bnrzifjly2vpdmfi': 1,
#  'bgvzlcanckxlyxnlcywgqxv0bybqb3j0zm9saw9zlcbcdxnpbmvzcybhbmqg': 1,
#  'umvhbcbfc3rhdgugtm90zxmsigfuzcbvdghlcibdyxnoia0krmxvd3muicbj': 1,
#  'zib5b3ugd291bgqgbglrzsb0bybpbnf1axjligfib3v0ihvzighlbhbpbmcg': 1,
#  'ew91ihrvzgf5ihdpdgggew91ciancmnhcgl0ywwgbmvlzhmsihbszwfzzsbj': 1,
#  'bgljaybvbib0agugbgluaybizwxvdybmb3igzgv0ywlscybhbmqgc3vibwlz': 1,
#  'c2lvbiancmzvcm0uicbuahggzm9yihlvdxigdgltzs4gifdvcmxkienhcgl0': 1,
#  'ywwgr3jvdxancg0kahr0cdovl3d3dy5tywlscgfpbc5jb20ncg0kahr0cdov': 1,
#  'l3d3dy5tywlscgfpbc5jb20ncg0kdqoncg0kdqoncg0kdqoncmxvdmuncg0k': 1,
#  'dqoncg0kdqoncg0kdqoncg0kdqoncg0kdqoncg0kdqoncg0kdqoncg0kdqon': 1,
#  'cg0kdqoncg0kdqoncg0kdqoncg0kdqoncg0kdqoncg0kdqoncg0kdqoncg0k': 1,
#  'dqoncg0kdqoncg0kdqoncg0kdqoncg0kbg92zq0kdqpzb3ugyxjlihjly2ll': 1,
#  'dmluzyb0aglzigvtywlsigfzigegc3vic2nyawjlcibvcibhzmzpbglhdgug': 1,
#  'c3vjynnjcmlizxigdqp0bybvchrpbibuzxr3b3jrliagswygew91ighhdmug': 1,
#  'cmvjzwl2zwqgdghpcybhcybhbiblcnjvcibvcib3b3vszcbsawtlia0kdg8g': 1,
#  'ymugdgfrzw4gb2zmig91cibsaxn0ihbszwfzzsbzzw5kigfuigvtywlsihrv': 1,
#  'ig5vcm1vcmvazxlvds5jb20uicbuagfuayancnlvdsbhbmqgagf2zsbhigdy': 1,
#  'zwf0igrhes5sb3zldqowotgxwfzlvjktmte1ewfmbdkzmdlrugfsmjm': 1,
#  'plan': 387,
#  'rolling': 31,
#  'nessus': 14,
#  'rpm': 1817,
#  'rh8': 15,
#  'miss': 91,
#  'already': 394,
#  'ille': 16,
#  'skyttä': 19,
#  'ville': 34,
#  'skytta': 16,
#  'iki': 19,
#  'fi': 61,
#  '_______________________________________________': 1226,
#  'list': 7228,
#  'freshrpms': 899,
#  'mailman': 1695,
#  'listinfo': 2261,
#  'hijacker': 10,
#  'high': 580,
#  '8': 1092,
#  '30': 1025,
#  'dalal': 4,
#  'mughrabi': 8,
#  'wa': 3472,
#  'palestinian': 51,
#  'woman': 318,
#  'participated': 6,
#  '1978': 7,
#  'bus': 28,
#  'hijacking': 6,
#  '36': 216,
#  'israeli': 13,
#  'american': 431,
#  'nature': 103,
#  'photographer': 7,
#  'gail': 5,
#  'ruban': 4,
#  'killed': 41,
#  'ha': 2736,
#  'school': 202,
#  'named': 75,
#  'apparently': 100,
#  'starting': 172,
#  'show': 491,
#  'sign': 181,
#  'wear': 35,
#  'fortunately': 20,
#  'united': 503,
#  'state': 1464,
#  'agency': 154,
#  'international': 292,
#  'development': 322,
#  'stepped': 13,
#  'money': 1645,
#  'help': 1002,
#  'renovate': 4,
#  'reason': 361,
#  'brickbat': 10,
#  'bb': 683,
#  'april': 22,
#  'shtml': 56,
#  'link': 1180,
#  'cnsnews': 5,
#  'viewforeignbureaus': 4,
#  'asp': 659,
#  'page': 753,
#  'foreignbureaus': 4,
#  'archi': 4,
#  '200208': 4,
#  'for20020807e': 4,
#  'html': 4379,
#  'praeterea': 4,
#  'censeo': 4,
#  'palestininem': 4,
#  'esse': 4,
#  'delendam': 4,
#  'mon': 182,
#  'nov': 28,
#  '25': 729,
#  '2002': 2968,
#  '06': 262,
#  '54': 157,
#  '49pm': 3,
#  '0000': 114,
#  'philip': 18,
#  'trickett': 3,
#  'wrote': 1391,
#  'overhead': 11,
#  'doe': 1060,
#  'add': 427,
#  'daily': 198,
#  'reading': 206,
#  'like': 2110,
#  'said': 1037,
#  'two': 725,
#  '2': 8136,
#  '3': 3663,
#  'month': 832,
#  'tell': 415,
#  'way': 1397,
#  'stop': 375,
#  'forging': 9,
#  'nonexistent': 1,
#  'actively': 41,
#  'moment': 167,
#  '1200': 26,
#  'bounce': 23,
#  'counting': 54,
#  'good': 932,
#  'job': 461,
#  'adsl': 20,
#  'otherwise': 96,
#  'would': 2115,
#  'throwing': 16,
#  'fit': 88,
#  'yes': 506,
#  'whitelist': 85,
#  'minimum': 82,
#  'required': 302,
#  'kevin': 189,
#  'ie': 2124,
#  'suberic': 65,
#  'dante': 2,
#  'hick': 2,
#  'hate': 69,
#  'people': 2267,
#  'fork': 953,
#  'ed': 252,
#  '37058400': 28,
#  'randal': 4,
#  'graf': 3,
#  'love': 245,
#  'gathering': 20,
#  'meatspace': 29,
#  'place': 532,
#  'home': 1321,
#  'ironic': 10,
#  'clerk': 5,
#  'irish': 621,
#  'linux': 3119,
#  'user': 2646,
#  'group': 1285,
#  'social': 232,
#  'event': 231,
#  'un': 680,
#  'subscription': 664,
#  'maintainer': 552,
#  'listmaster': 543,
#  'hello': 119,
#  'aaron': 4,
#  'schwartz': 9,
#  'npr': 15,
#  'weekend': 63,
#  'edition': 88,
#  'talking': 140,
#  'warchalking': 12,
#  'agree': 107,
#  'funny': 60,
#  'voice': 99,
#  'squeaky': 4,
#  'jealous': 3,
#  'got': 493,
#  'radio': 125,
#  'really': 670,
#  'wtf': 8,
#  'big': 530,
#  'deal': 305,
#  'yet': 350,
#  'see': 1202,
#  'anywhere': 167,
#  'probably': 402,
#  'pop': 86,
#  'org': 1410,
#  'later': 254,
#  'best': 872,
#  'regard': 249,
#  'bitbitch': 119,
#  'mailto': 1073,
#  'magnesium': 81,
#  '_nextpart_000_00b6_53d62c4c': 2,
#  'c4267a64': 2,
#  'sgvsbg8giq0kdqoncg0kdqoncg0kdqoncg0kpt09pt09pt09pt09pt09pt09': 2,
#  'pt09pt09pt09pt09pt09pt09pt09pt0nckludmvzdg1lbnqgaw4gdgvjag5v': 2,
#  'bg9nesb0agf0ihdpbgwgbwfrzsb5b3ugbw9uzxkudqo9pt09pt09pt09pt09': 2,
#  'pt09pt09pt09pt09pt09pt09pt09pt09pt09pq0kia0kqvmgu0vftibptibo': 2,
#  'qvrjt05btcbuvjoncianck1ha2luzybvdmvyighhbgygbwlsbglvbibkb2xs': 2,
#  'yxjzigv2zxj5idqgdg8gnsbtb250ahmgznjvbsb5b3vyighvbwu': 2,
#  'ieegb25l': 2,
#  'ihrpbwuncmludmvzdg1lbnqgb2ygb25sesakmjugvs5tlibeb2xsyxjzigxl': 2,
#  'dcdzigdldcb5b3ugb24gdghlihjvywqgdg8gzmluyw5jawfsihn1y2nlc3mu': 2,
#  'dqogdqpbtewgvehbtkttifrpifrirsbdt01qvvrfuibbr0ugqu5eifrirsbj': 2,
#  'tlrfuk5fvcahdqo9pt09pt09pt09pt09pt09pt09pt09pt09pt09pt09pt
#  'growing': 202,
#  'real': 640,
#  'time': 3267,
#  'communication': 503,
#  'platform': 204,
#  'im': 143,
#  'build': 498,
#  'osdn': 224,
#  'xim': 92,
#  'spamassassin': 1777,
#  'sighting': 469,
#  'sourceforge': 1355,
#  'thanks': 435,
#  'paul': 127,
#  'mouse': 62,
#  'thing': 987,
#  'clue': 84,
#  'saludos': 1,
#  'ulises': 9,
#  'speaking': 52,
#  'word': 531,
#  'wisdom': 30,
#  'message': 2420,
#  'dated': 47,
#  'thu': 199,
#  '22': 2641,
#  'aug': 460,
#  '13': 598,
#  '03': 213,
#  '57': 135,
#  'cdt': 7,
#  'ponce': 5,
#  'tony': 90,
#  'think': 1046,
#  'using': 986,
#  'component': 59,
#  'file': 1536,
#  'get': 3257,
#  'signature': 488,
#  'default': 289,
#  'many': 1058,
#  'diferent': 3,
#  'want': 1498,
#  'insert': 67,
#  'keyboard': 92,
#  'command': 226,
#  'another': 596,
#  'different': 506,
#  'possible': 390,
#  'sedit': 28,
#  'ahm': 2,
#  'object': 127,
#  'exmh': 1057,
#  'ability': 178,
#  'sigs': 9,
#  'demand': 111,
#  'create': 246,
#  'bunch': 56,
#  'sig': 44,
#  'beginning': 91,
#  'start': 685,
#  'load': 184,
#  'window': 871,
#  'menu': 93,
#  'item': 210,
#  'allow': 300,
#  'select': 386,
#  'listed': 133,
#  'mail': 2899,
#  'actually': 463,
#  'several': 312,
#  'though': 427,
#  'preference': 323,
#  'option': 2470,
#  'allows': 134,
#  'however': 462,
#  'added': 309,
#  'send': 1229,
#  'inserted': 23,
#  'directly': 143,
#  'existing': 142,
#  'prior': 59,
#  'composition': 14,
#  '6': 1555,
#  'choose': 169,
#  'additionally': 13,
#  'execute': 27,
#  'bit': 391,
#  'turned': 91,
#  'attempt': 113,
#  'stdout': 13,
#  'script': 328,
#  'hope': 229,
#  'seeya': 4,
#  'may': 1320,
#  'look': 769,
#  'sitting': 52,
#  'nothing': 369,
#  'waiting': 122,
#  'problem': 990,
#  'go': 1160,
#  'away': 316,
#  'fun': 136,
#  'redhat': 684,
#  'listman': 217,
#  '_nextpart_000_002b_83a1e322': 2,
#  '4d8b344b': 2,
#  'ls0tls0tls0tls0tls0tls0tls0tls0tls0tls0tls0tls0tls0nclroaxmgbwvzc2fnzsb3': 1,
#  'yxmgc2vudcbiesbfehbyzxnzierpcmvjdcbfbwfpbcbcbgfzdgvyify1ljesia0kew91ignh': 1,
#  'bibkb3dubg9hzcbpdcbmcm9toibodhrwoi8vd3d3lmzhc3ridwxrzw1hawwuy29tia0krxhw': 1,
#  'cmvzcybeaxjly3qgrw1hawwgqmxhc3rlcibpcybhihbvd2vyznvsigvtywlsig1hcmtldglu': 1,
#  'zyb0b29sisenci0tls0tls0tls0tls0tls0tls0tls0tls0tls0tls0tls0tls0ncg0kdqpe': 1,
#  'zwfyihnpci9tywrhbq0kdqpxaxroigdvb2qgcmvjb21tzw5kyxrpb24sssagzgvjawrlzcb0': 1,
#  'esdzigfjy291bnqgaw4gew91cg0ky291bnryesxmb3igaw52zxn0bwvudc5xzsboyxzligvx': 1,
#  'dwfsbhkgihjlc29sdmvkihrvihnwzw5kihrozsbyzxn0ig9mig91cg0kbgl2zxmgaw4gew91': 1,
#  'cibjb3vudhj5lllvdsboyxzlihrvicbtywtlihryyxzlbgluzybhcnjhbmdlbwvuda0kb2yg': 1,
#  'y29taw5nihrvieppseforvncvvjhlfnpvvriiefgukldqsxpbw1lzglhdgvsesb0byagbwvl': 1,
#  'dcb3axroig1ligzhy2ugdg8ncmzhy2ugyw5kihnlzsb0agugznvuzhmgcgh5c2ljywxsesx0': 1,
#  'agvuighhdmugaxqgdhjhbnnmzxjyzwqgihrvihlvdxincmfjy291bnquqwz0zxj3agljacbi': 1,
#  'b3roig9mihvzihdvdwxkihryyxzlbcb0b2dldghlcib0byb5b3vyignvdw50cnkgzm9ydqpz': 1,
#  'agfyaw5nigfuzcbpbw1lzglhdgugaw52zxn0bwvudcx0agvuig15igzhbwlsesb3awxsigpv': 1,
#  'aw4gbwugbgf0zxiudqonckfzihdligf3ywl0ihlvdxigdxjnzw50icbyzxbseswgc3ryawn0': 1,
#  'bhkgdghyb3vnacbtesbllw1hawwgzgf2c2f2qg1ha3rvb2iuy29tig9ydqogzgf2awrzyxzp': 1,
#  'bwjpqg1ha3rvb2iuy29ticbvcibtesbwcml2yxrlihbob25lig51bwjlciarodgyidegnjq2': 1,
#  'njg1mji5liagew91cg0kywjzb2x1dgugdhj1c3qgyw5kignvbmzpzgvudglhbgl0esbpcybo': 1,
#  'awdobhkgc29sawnpdgvkihrvihnlcnzlihvzigjldhrlci4ncg0kqmvzdcbyzwdhcmqnclbs': 1,
#  'su5drsbeqvzjrcbtqvzjtujjicagia': 1,
#  'date': 947,
#  'wed': 236,
#  '31': 508,
#  'jul': 262,
#  '15': 1071,
#  '23': 592,
#  '0100': 169,
#  'ronan': 13,
#  'cunniffe': 9,
#  'um': 20,
#  'test': 372,
#  'tee': 5,
#  'fifo': 10,
#  'read': 560,
#  'resulting': 44,
#  'reader': 119,
#  'hanging': 27,
#  'around': 460,
#  'forever': 106,
#  'realising': 4,
#  'never': 637,
#  'opened': 56,
#  'closed': 53,
#  'might': 522,
#  'ah': 62,
#  'gotchas': 3,
#  'everyone': 248,
#  'stumble': 9,
#  'writer': 61,
#  'pipe': 122,
#  'quickly': 132,
#  'block': 108,
#  'soon': 220,
#  'limited': 226,
#  'buffer': 61,
#  'fill': 339,
#  'epipe': 2,
#  'error': 548,
#  'usually': 116,
#  'terminal': 62,
#  'sigpipe': 3,
#  'signal': 77,
#  'typical': 41,
#  'someone': 469,
#  'creates': 26,
#  'anonymous': 45,
#  'forgets': 1,
#  'close': 160,
#  'fd': 136,
#  'process': 334,
#  'visa': 62,
#  'versa': 12,
#  'wonder': 84,
#  'eof': 24,
#  'various': 151,
#  'faq': 47,
#  'book': 388,
#  'discus': 169,
#  'topic': 49,
#  'depth': 31,
#  'death': 144,
#  'sensible': 7,
#  'behaviour': 25,
#  'observed': 8,
#  'luck': 61,
#  'cheer': 171,
#  'blf': 30,
#  'â': 255,
#  'surrealist': 2,
#  'take': 1031,
#  'brian': 98,
#  'foster': 23,
#  'dublin': 43,
#  'ireland': 102,
#  'change': 1075,
#  'lightbulb': 2,
#  'three': 360,
#  'calm': 21,
#  'utvinternet': 21,
#  'warthog': 7,
#  'bathtub': 11,
#  'mobile': 144,
#  '353': 64,
#  '0': 9786,
#  '86': 91,
#  '854': 9,
#  '9268': 9,
#  'brightly': 3,
#  'coloured': 5,
#  'machine': 273,
#  'tool': 398,
#  'exxonmobile': 9,
#  'whatever': 161,
#  'buy': 371,
#  'esso': 10,
#  'give': 718,
#  'damn': 48,
#  'global': 291,
#  'warming': 59,
#  'stopesso': 9,
#  'supported': 76,
#  'greenpeace': 9,
#  'friend': 449,
#  'earth': 126,
#  'numerous': 41,
#  'others': 323,
#  'ilug': 1121,
#  'head': 1319,
#  'title': 1131,
#  'dear': 211,
#  'homeowner': 51,
#  'meta': 764,
#  'equiv': 448,
#  '3d': 36612,
#  '3diso': 129,
#  'style': 3381,
#  'cs': 89,
#  'main': 207,
#  'font': 35837,
#  'family': 1537,
#  'verdana': 3484,
#  'arial': 5871,
#  'helvetica': 3191,
#  'sans': 2906,
#  'serif': 2891,
#  'size': 13337,
#  '12': 1032,
#  'px': 7,
#  'color': 9463,
#  '212121': 5,
#  'footer': 48,
#  '10px': 30,
#  '000000': 1845,
#  'decoration': 382,
#  'none': 459,
#  'ed1c24': 19,
#  'visited': 63,
#  'active': 129,
#  'f7941d': 5,
#  'hover': 79,
#  'yellow': 104,
#  'ffffff': 2353,
#  'e6e6e6': 5,
#  'body': 1965,
#  'bgcolor': 2871,
#  'dadada': 5,
#  'topmargin': 98,
#  '4': 3207,
#  'table': 4806,
#  'width': 9522,
#  '600': 216,
#  'border': 4192,
#  'cellspacing': 1745,
#  'cellpadding': 1703,
#  'alig': 13,
#  'n': 834,
#  'center': 5089,
#  'bordercolor': 547,
#  '000066': 557,
#  'class': 1065,
#  'f2f2f2': 5,
#  'tr': 10667,
#  'td': 17957,
#  '560': 30,
#  'align': 6704,
#  'p': 10525,
#  'b': 12284,
#  '0000cc': 124,
#  '000099': 60,
#  'interest': 516,
#  'rat': 26,
#  'lowest': 139,
#  'point': 557,
#  '40': 482,
#  'year': 1627,
#  '590': 16,
#  '50': 1722,
#  'valign': 1397,
#  'top': 1871,
#  'div': 3246,
#  '5': 3122,
#  'let': 573,
#  'u': 4242,
#  'shopping': 56,
#  'free': 2905,
#  'img': 2864,
#  'src': 2942,
#  '61': 418,
#  '129': 127,
#  '81': 516,
#  '74': 192,
#  'pix2': 15,
#  'age': 280,
#  'ad2': 7,
#  'gif': 2137,
#  '142': 39,
#  'height': 4726,
#  '218': 40,
#  'br': 16542,
#  'nationwide': 38,
#  'network': 663,
#  'lender': 104,
#  'hundred': 297,
#  'loan': 287,
#  'program': 1226,
#  'current': 397,
#  'situation': 162,
#  'ul': 433,
#  'li': 1704,
#  'refinance': 97,
#  'second': 387,
#  'mortgage': 311,
#  'debt': 229,
#  'consolidation': 56,
#  'improvement': 217,
#  'purchase': 294,
#  'please': 1779,
#  'href': 4167,
#  'rd': 41,
#  'yahoo': 787,
#  'dir': 58,
#  ...}

# %%
def keep_token(processed_token, threshold):
    if processed_token not in token_counter:
        return False
    else:
        return token_counter[processed_token] > threshold
keep_token('random', 10)
# Out:
# True

# %%
features = set()
for token in token_counter:
    if keep_token(token, 7000):
        features.add(token)
features
# Out:
# {'0',
#  '1',
#  '2',
#  '3d',
#  'b',
#  'br',
#  'color',
#  'com',
#  'face',
#  'font',
#  'http',
#  'list',
#  'nbsp',
#  'p',
#  'size',
#  'td',
#  'tr',
#  'width',
#  'www'}

# %%
features = list(features)
features
# Out:
# ['nbsp',
#  'com',
#  'http',
#  'face',
#  'width',
#  'www',
#  '0',
#  'tr',
#  '2',
#  'p',
#  'list',
#  'size',
#  'color',
#  'b',
#  'br',
#  '3d',
#  'td',
#  'font',
#  '1']

# %%
token_to_index_mapping = {t:i for t, i in  zip(features, range(len(features)))}
token_to_index_mapping
# Out:
# {'nbsp': 0,
#  'com': 1,
#  'http': 2,
#  'face': 3,
#  'width': 4,
#  'www': 5,
#  '0': 6,
#  'tr': 7,
#  '2': 8,
#  'p': 9,
#  'list': 10,
#  'size': 11,
#  'color': 12,
#  'b': 13,
#  'br': 14,
#  '3d': 15,
#  'td': 16,
#  'font': 17,
#  '1': 18}

# %%
import numpy as np

def message_to_count_vector(message):
    count_vector = np.zeros(len(features))
    
    processed_list_of_tokens = message_to_token_list(message)
    for token in processed_list_of_tokens:
        if token not in features:
            continue
        index = token_to_index_mapping[token]
        count_vector[index] += 1
    return count_vector

# %%
def df_to_X_y(dff):
    y = dff['CATEGORY'].to_numpy().astype(int)
    
    message_col = dff['MESSAGE']
    count_vectors = []
    for message in message_col:
        count_vector = message_to_count_vector(message)
        count_vectors.append(count_vector)
    X = np.array(count_vectors).astype(int)
    
    return X, y

# %%
X_train, y_train = df_to_X_y(train_df)
X_test, y_test = df_to_X_y(test_df)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler().fit(X_train)
X_train, X_test = scaler.transform(X_train), scaler.transform(X_test)
X_train
# Out:
# array([[0.        , 0.02369668, 0.00580271, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.00363636],
#        [0.        , 0.        , 0.00193424, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.00773694, ..., 0.        , 0.        ,
#         0.00727273],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.07109005, 0.05415861, ..., 0.20875421, 0.02028273,
#         0.05090909]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

lr = LogisticRegression().fit(X_train, y_train)
print(classification_report(y_test, lr.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88       798
#            1       1.00      0.37      0.54       362
#
#     accuracy                           0.80      1160
#    macro avg       0.89      0.69      0.71      1160
# weighted avg       0.85      0.80      0.77      1160

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier().fit(X_train, y_train)
print(classification_report(y_test, rf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92       798
#            1       0.88      0.74      0.81       362
#
#     accuracy                           0.89      1160
#    macro avg       0.89      0.85      0.86      1160
# weighted avg       0.89      0.89      0.89      1160
